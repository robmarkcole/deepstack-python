# %% [markdown]
# Placeholder for usage

# %%
from deepstack.core import DeepstackFace
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IP_ADDRESS = 'localhost'
PORT = '5000'

dsface = DeepstackFace(IP_ADDRESS, PORT)

# %%
# %%time
image_path = 'development/test-image2.jpg'

with open(image_path, "rb") as image_bytes:
    dsface.process_image_bytes(image_bytes)
    
print(dsface.attributes)

plt.imshow(Image.open(image_path));
# Out:
# {'faces': 2, 'matched_faces': {}, 'total_matched_faces': 0}
# CPU times: user 367 ms, sys: 52.6 ms, total: 420 ms
# Wall time: 14.9 s
